# %%
print("주피터 노트북 연동 성공")
# Out:
# 주피터 노트북 연동 성공

# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
#   Using cached pandas-3.0.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached matplotlib-3.11.0-cp311-cp311-win_amd64.whl.metadata (80 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 9.9/9.9 MB 51.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 12.6/12.6 MB 60.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 9.3/9.3 MB 57.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 8.3/8.3 MB 64.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 67.6 MB/s  0:00:00
# ...

# %% [markdown]
# 터미널에서 python.exe -m pip install --upgrade pip

# %%
import pandas as pd # pandas를 pd로 (외부 공학용 라이브러리, 생산성 빨라짐, 파이썬의 엑셀)
import numpy as np # 과학적 계산을 위한 라이브러리 (계산 속도가 수백배 빨라질 수 있음)
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

print("모든 패키지가 에러 없이 정상적으로 로드되었습니다.")
# Out:
# 모든 패키지가 에러 없이 정상적으로 로드되었습니다.
