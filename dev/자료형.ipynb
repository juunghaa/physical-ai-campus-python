# %% [markdown]
# # 파이썬 프로그래밍 기초
#
# ## 자료형
#
# ### 숫자형
#
# 자료형의 기본 : 숫자, 문자열, 불리언, 자료형 변환 예시 및 사용 방법에 대한 설명

# %%
# 정수형 

a = 123 # 변수 a에 123 숫자를 대입 
print(a)

# %%
a = -178
print(a)

# %%
a = 1.2
print(a)

# %%
type(a)

# %%
b = 4
type(b)

# %%
a = -3.45
print(a)

# %%
a = 4.24e4
print(a)

# %%
a = 4.24e-10
print(a)

# %%
# 8진수와 16진수
# 8진수(octal)는 0o 또는 0O 시작
# 16진수(hexadecimal)는 0x 또는 0X 시작 

a = 0o177
print(a)

# %%
b = 0x8ff
print(b)

# %%
type(b)

# %%
# 숫자를 활용한 연산자

a = 3
b = 4 
a + b

# %%
a - b

# %%
a * b

# %%
a / b

# %%
# x의 y 제곱은 x**y 로 표현함

a ** b

# %%
3 ** 4

# %%
# 나눗셈 후 나머지를 구하는 연산자는 % 임 

7 % 3

# %%
3 % 7

# %%
# 나눗셈 후 몫을 반환하는 // 연산자 

7 // 4

# %%
# 복합 연산자

a = 1
a = a + 1
print(a)

# %%
a = 1
a += 1
print(a)

# %%
a -= 1
print(a)

# %%
# 복합 연산자에는 *=, /=, //=, %=, **= 도 있음 

a **= 2
print(a)

# %%
a = 2
a *= 3
print(a)

# %% [markdown]
# ### 문자열 자료형

# %%
"Hello, Wprld!"

# %%
"""Life is too short, You need Python"""

# %%
'''Life is too short, 

You need Python'''

# %%
print('''Life is too short, 

You need Python''')

# %%
# 문자열에 작은 따옴표 포함하기 

food = "Python's favorite food is perl"
print(food)

# %%
# 문자열에 큰 따옴표 포함하기

say = '"Python is very easy." he says.'
print(say)

# %%
# 역슬래시를 사용해서 작은따옴표와 큰따옴표 문자열 포함하기

say = "\"Python is very easy.\" he says."
print(say)

# %%
# 여러 줄인 문자열을 변수에 대입하기 (\n은 줄바꿈)

multiline = "Life is too short\nYou need Python"
print(multiline)

# %%
# 연속된 작은 따옴표 3개 또는 큰 따옴표 3개를 사용하면 여러 줄인 문자열을 변수에 대입할 수 있음 

multiline = '''
Life is too short
You need Python
'''
print(multiline)

# %%
# 이스케이프 코드 예시 : \를 사용해서 문자열 안에 작은 따옴표나 큰 따옴표를 포함할 수 있음, \n은 줄바꿈을 의미함 
# \' : 작은 따옴표, \" : 큰 따옴표, \\ : 역슬래시, \n : 줄바꿈, \t : 탭, \r : 캐리지 리턴, \b : 백스페이스 등등

# %%
# 문자열 더해서 연결하기 

head = "Python"
tail = "is fun!"

head + tail

# %%
a = "Python" 
a * 5
# Out:
# 'PythonPythonPythonPythonPython'

# %%
# 문자열 곱하기 응용하기
print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ...
# My Program
# ...

# %%
# 문자열 길이 구하기

a = "Life is too short" 
len(a)
# Out:
# 17

# %%
# 문자열 인덱싱 (인덱싱은 0부터 시작)

a = "Life is too short, You need Python"
a[3]
# Out:
# 'e'

# %%
a[12]
# Out:
# 's'

# %%
a[-1] # 뒤에서부터 인덱싱
# Out:
# 'n'

# %%
# 문자열 슬라이싱

a = "Life is too short, You need Python"

b = a[0] + a[1] + a[2] + a[3]

print(b)
# Out:
# Life

# %%
a[0:4] # 문자열의 0번째부터 4번째까지 (4번째는 포함되지 않음)
# Out:
# 'Life'

# %%
a[19:] # 인덱스 19번째부터 끝까지
# Out:
# 'You need Python'

# %%
a[:17] # 처음부터 17번째까지
# Out:
# 'Life is too short'

# %%
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
a[19:-7] # 19번부터 뒤에서 7번째까지
# Out:
# 'You need'

# %%
a = "20010331Rainy"
date = a[:8]
weather = a[8:]
date
# Out:
# '20010331'

# %%
weather
# Out:
# 'Rainy1'

# %%
# Pithon 문자열을 Python으로 수정하기 

a = "Pithon"
a[1]
# Out:
# 'i'

# %%
a[1] = 'y' # 문자열은 바꿀 수 없는 타입
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a[1] = 'y'
#
# TypeError: 'str' object does not support item assignment

# %%
a[0] + 'y' + a[2:]
# Out:
# 'Python'

# %%
# 문자열 포매팅 (%d는 정수, %s는 문자열, %f는 부동소수점)

"I eat %d apples." %3
# Out:
# 'I eat 3 apples.'

# %%
# 문자열 바로 대입

"I eat %s apples." %"five"
# Out:
# 'I eat five apples.'

# %%
# 숫자값을 나타내는 변수로 대입

number = 3
"I eat %d apples." %number
# Out:
# 'I eat 3 apples.'

# %%
# 문자열 여러개 넣기

number = 10
day = "three"

"I eat %d apples and %s days." %(number, day)
# Out:
# 'I eat 10 apples and three days.'

# %%
# 소수점 표현하기

"%.4f" %3.141592
# Out:
# '3.1416'

# %%
"%10.4f" %3,141592 # 10자리 공간을 확보하고, 소수점 4자리까지 표현
# Out:
# ('    3.0000', 141592)

# %%
# format 함수를 사용한 문자열 포매팅

"I eat {0} apples.".format(3)
# Out:
# 'I eat 3 apples.'

# %%
"I eat {0} apples and {1} days.".format(3, "three")
# Out:
# 'I eat 3 apples and three days.'

# %%
number = 10
day = "three"
"I eat {0} apples and {1} days.".format(number, day)
# Out:
# 'I eat 10 apples and three days.'

# %%
# { 또는 } 문자 표현하기

"{{ and }}".format()
# Out:
# '{ and }'

# %%
# f문자열 포매팅 

name = '홍길동'
age = 30
f'나의 이름은 {name}입니다. 나이는 {age}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
age = 30
f'나는 내년이면 {age+1}살이 된다.'
# Out:
# '나는 내년이면 31살이 된다.'

# %%
y = 3.141592
f'{y:0.4f}' # 소수점 4자리까지만 표현 의미
# Out:
# '3.1416'

# %%
'{0:0.4f}'.format(y)
# Out:
# '3.1416'

# %%
'%.4f' %y
# Out:
# '3.1416'

# %%
# 문자열 관련 함수들 

a = "hobby"
a.count("b") # 함수를 적용한 것임, 메서드
# Out:
# 2

# %%
a = "Python is the best choice"

a.find("b") # 문자를 찾아 인덱스를 반환함 (맨 처음 인덱스만)
# Out:
# 14

# %%
a.find("k") # 없는 문자는 -1로 에러 코드 반환
# Out:
# -1

# %%
# 문자열 삽입 - join

",".join("abcd") # 조인할 문자를 먼저 쓰고, 대상 문자를 함수로 적어줌
# Out:
# 'a,b,c,d'

# %%
# 소문자를 대문자로 바꾸기 - upper
"apple".upper()
# Out:
# 'APPLE'

# %%
a = "hi"
a.upper()
# Out:
# 'HI'

# %%
# 대문자를 소문자로 - lower
a = "HI"
a.lower()
# Out:
# 'hi'

# %%
a = "hII"
a.lower()
a.upper()
# Out:
# 'HII'

# %%
# 왼쪽 공백 지우기 - lstrip

a = " hi "
a.lstrip()
# Out:
# 'hi '

# %%
# 오른쪽 공백 지우기 - rstrip

a.rstrip()
# Out:
# ' hi'

# %%
a.lstrip().rstrip()
# Out:
# 'hi'

# %%
a.strip()
# Out:
# 'hi'

# %%
b = " h i "
b.strip()
# Out:
# 'h i'

# %%
# 문자열 바꾸기

a = "Life is too long"
a.replace("long", "short").replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
# 문자열 나누기 

a = "Life is too short"
a.split() # 공백을 기준으로 분리하여 리스트 형태로 만들어줌
# Out:
# ['Life', 'is', 'too', 'short']

# %%
# 문자열이 알파벳으로 구성되어 있는지 확인 - isalpha

s = "Python3"
s.isalpha() # 알파벳이 맞으면 True, 아니면 False를 리턴함
# Out:
# False

# %%
s = "Hello World"
s.isalpha() # 공백도 false로 판단함
# Out:
# False

# %%
# 문자열이 숫자로만 되어 있는지 확인 - isdigit

s = "12345"
s.isdigit()
# Out:
# True

# %%
s = "안녕"
s.isalpha() # 영어 말고도 문자가 많잖아.. 문자들을 다 aplha로 인식하는 것 같음
# Out:
# True

# %% [markdown]
# 변수 a에 정수 10을, 변수 b에 실수 3.5를 저장하고, 두 수의 합과 곱을 출력하는 코드를 작성하세요.

# %%
a = 10
b = 3.5
f'a+b = {a+b}, a*b = {a*b}'
# Out:
# 'a+b = 13.5, a*b = 35.0'

# %% [markdown]
# 문자열 first에 'Python', second에 'Hello'를 저장한 뒤 두 문자열을 하나로 연결해 출력하는 코드를 작성하세요.

# %%
first = "Python"
second = "Hello"

first +' '+ second
# Out:
# 'Python Hello'

# %% [markdown]
# 문자열 word에 'python'을 저장하고, 첫 글자와 마지막 글자를 출력하는 코드를 작성하세요.

# %%
word = "python"

f'{word[0]}, {word[5]}'
# Out:
# 'p, n'

# %% [markdown]
# 변수 'x'에 7, 변수 y에 3을 저장하고, 나눗셈 결과의 몫과 나머지를 출력하는 코드를 작성하세요.

# %%
x = 7
y = 3

f'몫 = {7//3}, 나머지 = {7%3}'
# Out:
# '몫 = 2, 나머지 = 1'

# %% [markdown]
# 변수 num에 값 4를 저장하고, num을 3번 반복한 문자열을 출력하는 코드를 작성하세요.

# %%
num = "4"

f'{num*3}'
# print(num*3)
# Out:
# '444'
