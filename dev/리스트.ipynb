# %% [markdown]
# ### 리스트 자료형
#
# 리스트 : 생성, 인덱싱, 슬라이싱, 반복, 변경 가능한 (mutable) 성질이 있음

# %%
# 리스트 예시

odd = [1,3,5,7,9]

odd
# Out:
# [1, 3, 5, 7, 9]

# %%
type(odd)
# Out:
# list

# %%
a = []
b = [1,2,3]
c = ["Life", "is", "too", "short"]
d = [1,2,"Life", "is"]
e = [1,2, ["Life", "is"]]

e
# Out:
# [1, 2, ['Life', 'is']]

# %%
e[2]
# Out:
# ['Life', 'is']

# %%
f = list()
f
# Out:
# []

# %%
f = []
f
# Out:
# []

# %%
# 리스트 인덱싱 

a = [1,2,3]
a[0]
# Out:
# 1

# %%
a[0]+a[2]
# Out:
# 4

# %%
a[-1]
# Out:
# 3

# %%
a = [1,2,3,['a', 'b', 'c']]
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[-1][0]
# Out:
# 'a'

# %%
# 리스트의 슬라이싱 

a = [1,2,3,4,5]
a[0:2]
# Out:
# [1, 2]

# %%
a = "12345"
a[0:2]
# Out:
# '12'

# %%
a = [1,2,3,4,5]
b = a[:2]
c = a[2:]

b
# Out:
# [1, 2]

# %%
# 리스트 연산하기

a = [1,2,3]
b = [4,5,6]

a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 반복하기

a = [1,2,3]
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트 길이 구하기 

a = [1,2,3]
len(a)
# Out:
# 3

# %%
# 리스트 연산 오류 

a = [1,2,3]
a[2] + 'hi'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 # 리스트 연산 오류
#       2
#       3 a = [1,2,3]
# ----> 4 a[2] + 'hi'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a) # str은 요소를 문자열로 바꿔줌
# Out:
# '[1, 2, 3]'

# %%
str(a[2]) + 'hi'
# Out:
# '3hi'

# %%
int("4") +3
# Out:
# 7

# %%
# 리스트의 값 수정하기 

a = [1,2,3]
a[2] = 4

a
# Out:
# [1, 2, 4]

# %%
# del로 리스트의 요소를 삭제함 

a = [1,2,3]
del(a[2])

a
# Out:
# [1, 2]

# %%
a = [1,2,3,4]
del a[2:]

a
# Out:
# [1, 2]

# %%
# 리스트에 요소 추가하기

a = [1,2,3]
a.append(4)

a
# Out:
# [1, 2, 3, 4]

# %%
a.append([5,6])
a
# Out:
# [1, 2, 3, 4, [5, 6], [5, 6], [5, 6]]

# %%
# 리스트 정렬하기 

a = [1,4,3,2]
a.sort() # 오름차순 정렬 

a
# Out:
# [1, 2, 3, 4]

# %%
a = ['a', 'c', 'b']
a.sort()
a
# Out:
# ['a', 'b', 'c']

# %%
a = ['가', '다', '나']
a.sort()

a
# Out:
# ['가', '나', '다']

# %%
# 리스트 뒤집기

a = ['a','c','b']
a.reverse()

a
# Out:
# ['b', 'c', 'a']

# %%
# 인덱스 반환 

a = [1,2,3]
a.index(3) # 내가 찾는 요소의 인덱스를 반환함
# Out:
# 2

# %%
a.index(1)
# Out:
# 0

# %%
# 리스트에 요소를 삽입함

a = [1,2,3]
a.insert(0, 4) # 삽입할 위치와 삽입할 요소 

a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3,5)

a
# Out:
# [4, 1, 2, 5, 3]

# %%
# 리스트 요소 제거 

a = [1,2,3,1,2,3]
a.remove(3) # 첫번째 3이라는 요소를 제거함 

a
# Out:
# [1, 2, 1, 2, 3]

# %%
a.remove(3) # 같은 요소들을 다 지우려면 여러번 반복시켜야겠네! (조건은.. 리스트 개수가 줄어들지 않을때까지 반복시키면 될 듯?)
a
# Out:
# [1, 2, 1, 2]

# %%
# 리스트 요소 꺼내기

a = [1,2,3]
a.pop() # 리스트 제일 뒤에 요소를 꺼냄
# Out:
# 3

# %%
a # pop하고 나면 해당 값은 빠져나감
# Out:
# [1, 2]

# %%
# 리스트에 포함된 요소의 개수 세기 

a = [1,2,3,1]
a.count(1)
# Out:
# 2

# %%
# 리스트 확장 

a = [1,2,3]
a.extend([4,5]) # append랑 다르게 요소 자체가 붙여짐! 

a
# Out:
# [1, 2, 3, 4, 5]

# %%
a + [4,5]
# Out:
# [1, 2, 3, 4, 5, 4, 5]

# %%
a = [1,2,3]
a+=[4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 리스트 numbers에 [1,2,3,4,5]를 저장하고, 리스트의 첫번째 요소와 마지막 요소를 출력하세요.

# %%
numbers = [1,2,3,4,5]
f'{numbers[0]}, {numbers[-1]}'
# Out:
# '1, 5'

# %% [markdown]
# 리스트items에 apple, banana를 저장한 뒤, orange를 추가하고 결과리스트를 출력하세요.

# %%
items = ['apple', 'banana']
items.append('orange')

items
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# 리스트 a에 [1,2], b에 [3,4]를 저장하고 두 리스트를 합쳐 새로운 리스트를 만든 뒤 출력하세요.

# %%
a = [1,2]
b = [3,4]

c = a+b
c
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 리스트 fruits에 apple,banana, cherry, banana가 있을 때 banana가 몇 개 들어있는지 출력하세요.

# %%
fruits = ['apple', 'banana', 'cherry', 'banana']
fruits.count('banana')
# Out:
# 2

# %% [markdown]
# 리스트 nums에 [1,3,5,7,9]를 저장하고, 리스트의 앞에서 세 개 요소만 슬라이싱하여 출력하세요.

# %%
nums = [1,3,5,7,9]
nums[0:3]
# Out:
# [1, 3, 5]
