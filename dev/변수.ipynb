# %% [markdown]
# ### 변수 (자료형의 값을 저장하는 공간)
#
# 변수 : 네이밍 규칙, 할당, 스코프 (지역/전역), 할당시 복사/참조 차이

# %%
# 변수 예제 (c나 java의 경우 변수 타입(자료형)을 지정해주지만, python은 지정할 필요가 없음)

a = 1
b = "Python1"
c = [1,2,3]

# %%
# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_) 만 사용할 수 있음
# 2. 숫자로 시작할 수 없음
# 예약어는 사용할 수 없음 
# 대소문자 구분함

# %%
# 올바른 변수명 예시

name = "홍길동"
age = 25
user_name = "gildong"
userName = "gildong2"
_private = "비공개"
count1 = 10

# %%
# 잘못된 변수명 예시
1name = "gildong" # 숫자로 시작하면 안됨
# Out:
#   Cell In[6], line 2
#     1name = "gildong" # 숫자로 시작하면 안됨
#     ^
# SyntaxError: invalid decimal literal

# %%
user-name = "gildong" # 하이픈 사용하면 안됨
# Out:
#   Cell In[7], line 1
#     user-name = "gildong" # 하이픈 사용하면 안됨
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
if = 10 # 예약어 사용 안 됨
# Out:
#   Cell In[8], line 1
#     if = 10 # 예약어 사용 안 됨
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 파이썬 예약어
#
# False, None, True, and, as, assert, break, class, continue, def, del, elif, else, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with, yield

# %%
# 변수란

a = [1,2,3]
id(a) # 변수가 가리키는 메모리 주소
# Out:
# 3056756233088

# %%
# 리스트를 복사 할 때

a = [1,2,3]
b = a

# %%
id(a)
# Out:
# 3056757763648

# %%
id(b)
# Out:
# 3056757763648

# %%
a is b # a와 b가 가리키는 객체가 같은가?
# Out:
# True

# %%
a
# Out:
# [1, 2, 3]

# %%
a[1] = 4 # 리스트는 수정 가능했지?

# %%
a
# Out:
# [1, 4, 3]

# %%
b # 같은 객체를 가리키므로 같이 바뀜
# Out:
# [1, 4, 3]

# %%
# b 변수를 생성할 때, a 변수의 값을 가져와 다른 주소를 가리키도록 만드는 방법 (값만 복사하겠다는 것)

a = [1,2,3]
b = a[:]
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b # b의 값은 바뀌지 않은 것 체크!
# Out:
# [1, 2, 3]

# %%
a = [1,2,3]
b = a.copy()
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
# 변수를 만드는 여러가지 방법

a, b = ("python", "life") # 튜플 자체를 넣고 싶다면 변수 하나만 써서 넣어줘야 함! ... <<-- 파이썬 문법의 모호성...

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
(a,b) = "python", "life"

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
a = 3
b = 5
a, b = b, a

# %%
a
# Out:
# 5

# %%
b
# Out:
# 3

# %% [markdown]
# 변수 radius에 5를 저장하고, 원의 면적을 계산하여 출력하는 코드를 작성하세요. (원의 면적: 3.14*radius**2)

# %%
radius = 5
area = 3.14 * radius ** 2

area
# Out:
# 78.5
